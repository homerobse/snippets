# %% [markdown]
# https://pytorch.org/docs/stable/notes/cuda.html
#
# Checking torch.cuda functions below

# %%
import torch

# %%
torch.cuda.device('cuda')

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 3050 Ti Laptop GPU'

# %%
torch.cuda.get_device_properties('cuda'), torch.cuda.get_device_properties(0), torch.cuda.get_device_properties(None)
# Out:
# (_CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Ti Laptop GPU', major=8, minor=6, total_memory=4095MB, multi_processor_count=20),
#  _CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Ti Laptop GPU', major=8, minor=6, total_memory=4095MB, multi_processor_count=20),
#  _CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Ti Laptop GPU', major=8, minor=6, total_memory=4095MB, multi_processor_count=20))

# %%
torch.cuda.get_device_capability()
# Out:
# (8, 6)

# %%
torch.cuda.default_stream()
# Out:
# <torch.cuda.Stream device=cuda:0 cuda_stream=0x0>

# %%
torch.cuda.get_allocator_backend()
# Out:
# 'native'

# %%
torch.cuda.get_arch_list()
# Out:
# ['sm_50', 'sm_60', 'sm_61', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90']

# %%
torch.cuda.get_gencode_flags()
# Out:
# '-gencode compute=compute_50,code=sm_50 -gencode compute=compute_60,code=sm_60 -gencode compute=compute_61,code=sm_61 -gencode compute=compute_70,code=sm_70 -gencode compute=compute_75,code=sm_75 -gencode compute=compute_80,code=sm_80 -gencode compute=compute_86,code=sm_86 -gencode compute=compute_90,code=sm_90'

# %%
torch.cuda.get_sync_debug_mode()
# Out:
# 0

# %%
torch.cuda.get_sync_debug_mode()
# Out:
# 0

# %%
torch.cuda.list_gpu_processes()
# Out:
# 'pynvml module not found, please install pynvml'

# %%
help(torch.cuda.manual_seed)
# Out:
# Help on function manual_seed in module torch.cuda.random:
#
# manual_seed(seed: int) -> None
#     Set the seed for generating random numbers for the current GPU.
#
#     It's safe to call this function if CUDA is not available; in that
#     case, it is silently ignored.
#
#     Args:
#         seed (int): The desired seed.
#
#     .. warning::
#         If you are working with a multi-GPU model, this function is insufficient
#         to get determinism.  To seed all GPUs, use :func:`manual_seed_all`.

# %%
print(torch.cuda.memory_summary())
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from large pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |       from small pool |      0 B   |      0 B   |      0 B   |      0 B   |
# |---------------------------------------------------------------------------|
# | Active memory         |      0 B   |      0 B   |      0 B   |      0 B   |
# ...

# %%
# torch.cuda.utilization()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File C:\ProgramData\miniconda3\envs\metrics\Lib\site-packages\torch\cuda\__init__.py:56
#      55 try:
# ---> 56     import pynvml  # type: ignore[import]
#      58     _HAS_PYNVML = True
#
# ModuleNotFoundError: No module named 'pynvml'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 torch.cuda.utilization()
#
# File C:\ProgramData\miniconda3\envs\metrics\Lib\site-packages\torch\cuda\__init__.py:931, in utilization(device)
#     919 def utilization(device: Optional[Union[Device, int]] = None) -> int:
#     920     r"""Return the percent of time over the past sample period during which one or
#     921     more kernels was executing on the GPU as given by `nvidia-smi`.
#     922
#    (...)
# ...

# %%
help(torch.cuda.mem_get_info)
torch.cuda.mem_get_info()
# Out:
# Help on function mem_get_info in module torch.cuda.memory:
#
# mem_get_info(device: Union[int, str, torch.device, NoneType] = None) -> Tuple[int, int]
#     Return the global free and total GPU memory for a given device using cudaMemGetInfo.
#
#     Args:
#         device (torch.device or int, optional): selected device. Returns
#             statistic for the current device, given by :func:`~torch.cuda.current_device`,
#             if :attr:`device` is ``None`` (default).
#
#     .. note::
#         See :ref:`cuda-memory-management` for more
#         details about GPU memory management.
# (3463761102, 4294508544)
